# %% [markdown]
# ## 3. Implementando os Simuladores para o Caso Exponencial
#
# Cenário $\lambda = 1$ e $\mu  = 2$
#
# Descrição: Considere uma fila M/M/1, em que chegadas ocorrem segundo um fluxo Poisson com taxa 1 chegadas/segundo e serviços são tais que cada serviço é distribuído exponencialmente com média 1/2 segundo. Implemente dois simuladores.

# %%
import random

# %%
import heapq
import random

def simulate2(arrival_rate, service_rate, max_steps=1000):
    
    simulation_time = total_arrivals = total_departures = total_waiting_time = 0
    events = []
    arrivals_queue = []
    heapq.heappush(events, (random.expovariate(arrival_rate), 'chegada'))

    while simulation_time < max_steps:
        next_event_time, event_type = heapq.heappop(events)
        
        simulation_time = next_event_time
        
        if event_type == 'chegada':
            #print("Arrival")
            total_arrivals += 1
            
            heapq.heappush(events, (simulation_time + random.expovariate(arrival_rate), 'chegada'))
            
            if total_arrivals - total_departures == 1:
                heapq.heappush(events, (simulation_time + random.expovariate(service_rate), 'saida'))
            if total_arrivals - total_departures > 1:
                arrivals_queue.append(simulation_time)
            
        else:
            #print("Departure")
            total_departures += 1

            if len(arrivals_queue) > 0:
                total_waiting_time += simulation_time - arrivals_queue.pop(0)
            
            if total_arrivals > total_departures:
                heapq.heappush(events, (simulation_time + random.expovariate(service_rate), 'saida'))
        
    average_waiting_time = total_waiting_time / (total_departures)
    average_clients_in_system = total_arrivals / simulation_time

    return {
        "average_waiting_time": average_waiting_time,
        "average_clients_in_system": average_clients_in_system
    }

# %%
print(simulate2(1,2,10000))
# Out:
# Arrivals Queue:  []
# Arrivals Queue:  [2.2344616216077022]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [2.995526209701816]
# Arrivals Queue:  []
# Arrivals Queue:  [4.33639502128235]
# Arrivals Queue:  [4.33639502128235, 4.782629022063045]
# Arrivals Queue:  [4.33639502128235, 4.782629022063045, 4.9730361429918775]
# Arrivals Queue:  [4.782629022063045, 4.9730361429918775]
# Arrivals Queue:  [4.9730361429918775]
# Arrivals Queue:  []
# Arrivals Queue:  [7.588499720647063]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [8.370050905769896]
# Arrivals Queue:  [8.370050905769896, 8.380116261104074]
# Arrivals Queue:  [8.380116261104074]
# Arrivals Queue:  []
# Arrivals Queue:  [9.587025237110598]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [17.37575703983006]
# Arrivals Queue:  [17.37575703983006, 17.643542301076312]
# Arrivals Queue:  [17.643542301076312]
# Arrivals Queue:  []
# Arrivals Queue:  [18.50080383233948]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [20.67886018355755]
# Arrivals Queue:  []
# Arrivals Queue:  [20.98628242554159]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [23.55825668057026]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [25.69274224067881]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [28.7770853154146]
# Arrivals Queue:  []
# Arrivals Queue:  [29.710964748125168]
# Arrivals Queue:  [29.710964748125168, 29.86250200706555]
# Arrivals Queue:  [29.86250200706555]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [32.410326450816]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [33.682858596576715]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [35.630107640908584]
# Arrivals Queue:  [35.630107640908584, 35.93233288238076]
# Arrivals Queue:  [35.93233288238076]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [51.40122828474674]
# Arrivals Queue:  [51.40122828474674, 53.35374425897959]
# Arrivals Queue:  [51.40122828474674, 53.35374425897959, 53.746369325968125]
# Arrivals Queue:  [51.40122828474674, 53.35374425897959, 53.746369325968125, 53.7639615307759]
# Arrivals Queue:  [53.35374425897959, 53.746369325968125, 53.7639615307759]
# Arrivals Queue:  [53.746369325968125, 53.7639615307759]
# Arrivals Queue:  [53.746369325968125, 53.7639615307759, 54.71981203880968]
# Arrivals Queue:  [53.7639615307759, 54.71981203880968]
# Arrivals Queue:  [53.7639615307759, 54.71981203880968, 55.074803552528415]
# Arrivals Queue:  [54.71981203880968, 55.074803552528415]
# Arrivals Queue:  [54.71981203880968, 55.074803552528415, 55.83428447366301]
# Arrivals Queue:  [55.074803552528415, 55.83428447366301]
# Arrivals Queue:  [55.83428447366301]
# Arrivals Queue:  [55.83428447366301, 56.531817549490476]
# Arrivals Queue:  [55.83428447366301, 56.531817549490476, 56.61413219817216]
# Arrivals Queue:  [56.531817549490476, 56.61413219817216]
# Arrivals Queue:  [56.531817549490476, 56.61413219817216, 56.797479555701614]
# Arrivals Queue:  [56.531817549490476, 56.61413219817216, 56.797479555701614, 57.445483371167285]
# Arrivals Queue:  [56.61413219817216, 56.797479555701614, 57.445483371167285]
# Arrivals Queue:  [56.797479555701614, 57.445483371167285]
# Arrivals Queue:  [57.445483371167285]
# Arrivals Queue:  [57.445483371167285, 58.435370271726576]
# Arrivals Queue:  [58.435370271726576]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [65.74788499914507]
# Arrivals Queue:  []
# Arrivals Queue:  [66.05969384980182]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [67.85349319130418]
# Arrivals Queue:  []
# Arrivals Queue:  [68.63894114202239]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [72.73005996860489]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [80.66654253178254]
# Arrivals Queue:  [80.66654253178254, 80.89013621612769]
# Arrivals Queue:  [80.89013621612769]
# Arrivals Queue:  [80.89013621612769, 81.6038378872447]
# Arrivals Queue:  [80.89013621612769, 81.6038378872447, 82.73487423738209]
# Arrivals Queue:  [80.89013621612769, 81.6038378872447, 82.73487423738209, 82.78303888792898]
# Arrivals Queue:  [81.6038378872447, 82.73487423738209, 82.78303888792898]
# Arrivals Queue:  [82.73487423738209, 82.78303888792898]
# Arrivals Queue:  [82.78303888792898]
# Arrivals Queue:  [82.78303888792898, 84.33554592258601]
# Arrivals Queue:  [84.33554592258601]
# Arrivals Queue:  []
# Arrivals Queue:  [85.2656054915871]
# Arrivals Queue:  [85.2656054915871, 85.66751242343125]
# Arrivals Queue:  [85.66751242343125]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [97.34065089035401]
# Arrivals Queue:  [97.34065089035401, 97.37494075675001]
# Arrivals Queue:  [97.34065089035401, 97.37494075675001, 97.57730372547866]
# Arrivals Queue:  [97.34065089035401, 97.37494075675001, 97.57730372547866, 97.98914487315939]
# Arrivals Queue:  [97.34065089035401, 97.37494075675001, 97.57730372547866, 97.98914487315939, 98.11199286410671]
# Arrivals Queue:  [97.37494075675001, 97.57730372547866, 97.98914487315939, 98.11199286410671]
# Arrivals Queue:  [97.57730372547866, 97.98914487315939, 98.11199286410671]
# Arrivals Queue:  [97.57730372547866, 97.98914487315939, 98.11199286410671, 99.6912527167711]
# Arrivals Queue:  [97.98914487315939, 98.11199286410671, 99.6912527167711]
# Arrivals Queue:  [98.11199286410671, 99.6912527167711]
# Arrivals Queue:  [98.11199286410671, 99.6912527167711, 100.76515513490067]
# Arrivals Queue:  [99.6912527167711, 100.76515513490067]
# Arrivals Queue:  [99.6912527167711, 100.76515513490067, 102.23297186534859]
# Arrivals Queue:  [99.6912527167711, 100.76515513490067, 102.23297186534859, 102.57655695197204]
# Arrivals Queue:  [100.76515513490067, 102.23297186534859, 102.57655695197204]
# Arrivals Queue:  [102.23297186534859, 102.57655695197204]
# Arrivals Queue:  [102.23297186534859, 102.57655695197204, 103.39145218139232]
# Arrivals Queue:  [102.57655695197204, 103.39145218139232]
# Arrivals Queue:  [103.39145218139232]
# Arrivals Queue:  []
# Arrivals Queue:  [104.58608257164025]
# Arrivals Queue:  [104.58608257164025, 105.0113179259802]
# Arrivals Queue:  [105.0113179259802]
# Arrivals Queue:  []
# Arrivals Queue:  [106.55108660953658]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [108.47844775183208]
# Arrivals Queue:  [108.47844775183208, 108.592089515111]
# Arrivals Queue:  [108.592089515111]
# Arrivals Queue:  [108.592089515111, 109.46848603902863]
# Arrivals Queue:  [109.46848603902863]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [111.88976819756522]
# Arrivals Queue:  [111.88976819756522, 112.82977550353253]
# Arrivals Queue:  [111.88976819756522, 112.82977550353253, 113.05632545003442]
# Arrivals Queue:  [111.88976819756522, 112.82977550353253, 113.05632545003442, 113.52114622260144]
# Arrivals Queue:  [112.82977550353253, 113.05632545003442, 113.52114622260144]
# Arrivals Queue:  [113.05632545003442, 113.52114622260144]
# Arrivals Queue:  [113.52114622260144]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [118.18430250238204]
# Arrivals Queue:  [118.18430250238204, 118.26330655227191]
# Arrivals Queue:  [118.26330655227191]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [121.00594467555722]
# Arrivals Queue:  [121.00594467555722, 121.08871994685815]
# Arrivals Queue:  [121.00594467555722, 121.08871994685815, 121.20530962543826]
# Arrivals Queue:  [121.00594467555722, 121.08871994685815, 121.20530962543826, 121.38823079977335]
# Arrivals Queue:  [121.00594467555722, 121.08871994685815, 121.20530962543826, 121.38823079977335, 121.45697884181344]
# Arrivals Queue:  [121.08871994685815, 121.20530962543826, 121.38823079977335, 121.45697884181344]
# Arrivals Queue:  [121.20530962543826, 121.38823079977335, 121.45697884181344]
# Arrivals Queue:  [121.38823079977335, 121.45697884181344]
# Arrivals Queue:  [121.45697884181344]
# Arrivals Queue:  [121.45697884181344, 125.08418890739516]
# Arrivals Queue:  [125.08418890739516]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [131.45047533472902]
# Arrivals Queue:  [131.45047533472902, 131.7485075610469]
# Arrivals Queue:  [131.7485075610469]
# Arrivals Queue:  []
# Arrivals Queue:  [132.66566462770052]
# Arrivals Queue:  [132.66566462770052, 133.08949499874774]
# Arrivals Queue:  [133.08949499874774]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [141.27622845104761]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [147.60014024155146]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [157.6195858742396]
# Arrivals Queue:  [157.6195858742396, 157.63830781972646]
# Arrivals Queue:  [157.6195858742396, 157.63830781972646, 157.73233140523436]
# Arrivals Queue:  [157.6195858742396, 157.63830781972646, 157.73233140523436, 157.73847676701334]
# Arrivals Queue:  [157.6195858742396, 157.63830781972646, 157.73233140523436, 157.73847676701334, 157.86770152988387]
# Arrivals Queue:  [157.63830781972646, 157.73233140523436, 157.73847676701334, 157.86770152988387]
# Arrivals Queue:  [157.73233140523436, 157.73847676701334, 157.86770152988387]
# Arrivals Queue:  [157.73233140523436, 157.73847676701334, 157.86770152988387, 158.73746244021086]
# Arrivals Queue:  [157.73847676701334, 157.86770152988387, 158.73746244021086]
# Arrivals Queue:  [157.86770152988387, 158.73746244021086]
# Arrivals Queue:  [157.86770152988387, 158.73746244021086, 161.13276042374562]
# Arrivals Queue:  [158.73746244021086, 161.13276042374562]
# Arrivals Queue:  [158.73746244021086, 161.13276042374562, 161.55096550993588]
# Arrivals Queue:  [161.13276042374562, 161.55096550993588]
# Arrivals Queue:  [161.13276042374562, 161.55096550993588, 162.0441283226798]
# Arrivals Queue:  [161.55096550993588, 162.0441283226798]
# Arrivals Queue:  [162.0441283226798]
# Arrivals Queue:  []
# Arrivals Queue:  [163.60328112458416]
# Arrivals Queue:  [163.60328112458416, 164.22071832599897]
# Arrivals Queue:  [163.60328112458416, 164.22071832599897, 164.4072980749956]
# Arrivals Queue:  [163.60328112458416, 164.22071832599897, 164.4072980749956, 164.8509235844585]
# Arrivals Queue:  [163.60328112458416, 164.22071832599897, 164.4072980749956, 164.8509235844585, 164.95453688417166]
# Arrivals Queue:  [164.22071832599897, 164.4072980749956, 164.8509235844585, 164.95453688417166]
# Arrivals Queue:  [164.22071832599897, 164.4072980749956, 164.8509235844585, 164.95453688417166, 165.21909171620828]
# Arrivals Queue:  [164.4072980749956, 164.8509235844585, 164.95453688417166, 165.21909171620828]
# Arrivals Queue:  [164.8509235844585, 164.95453688417166, 165.21909171620828]
# Arrivals Queue:  [164.95453688417166, 165.21909171620828]
# Arrivals Queue:  [165.21909171620828]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [168.94243596952975]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [174.15342885830285]
# Arrivals Queue:  []
# Arrivals Queue:  [174.28917267955094]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [180.28306012658]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [180.94585219002414]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [182.9377997120609]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [192.33677912139348]
# Arrivals Queue:  [192.33677912139348, 192.61613964289924]
# Arrivals Queue:  [192.61613964289924]
# Arrivals Queue:  [192.61613964289924, 192.82055416941972]
# Arrivals Queue:  [192.82055416941972]
# Arrivals Queue:  [192.82055416941972, 193.40687921005116]
# Arrivals Queue:  [193.40687921005116]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [199.00784494951432]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [202.39677632595678]
# Arrivals Queue:  [202.39677632595678, 202.6689925144652]
# Arrivals Queue:  [202.39677632595678, 202.6689925144652, 202.7993674335902]
# Arrivals Queue:  [202.6689925144652, 202.7993674335902]
# Arrivals Queue:  [202.6689925144652, 202.7993674335902, 203.0232404436839]
# Arrivals Queue:  [202.6689925144652, 202.7993674335902, 203.0232404436839, 203.29316622904315]
# Arrivals Queue:  [202.7993674335902, 203.0232404436839, 203.29316622904315]
# Arrivals Queue:  [202.7993674335902, 203.0232404436839, 203.29316622904315, 204.32136184136274]
# Arrivals Queue:  [203.0232404436839, 203.29316622904315, 204.32136184136274]
# Arrivals Queue:  [203.0232404436839, 203.29316622904315, 204.32136184136274, 204.69614434456392]
# Arrivals Queue:  [203.29316622904315, 204.32136184136274, 204.69614434456392]
# Arrivals Queue:  [203.29316622904315, 204.32136184136274, 204.69614434456392, 205.179108482747]
# Arrivals Queue:  [203.29316622904315, 204.32136184136274, 204.69614434456392, 205.179108482747, 205.55576570818147]
# Arrivals Queue:  [204.32136184136274, 204.69614434456392, 205.179108482747, 205.55576570818147]
# Arrivals Queue:  [204.32136184136274, 204.69614434456392, 205.179108482747, 205.55576570818147, 205.8573944273258]
# Arrivals Queue:  [204.69614434456392, 205.179108482747, 205.55576570818147, 205.8573944273258]
# Arrivals Queue:  [204.69614434456392, 205.179108482747, 205.55576570818147, 205.8573944273258, 206.79534114230603]
# Arrivals Queue:  [205.179108482747, 205.55576570818147, 205.8573944273258, 206.79534114230603]
# Arrivals Queue:  [205.55576570818147, 205.8573944273258, 206.79534114230603]
# Arrivals Queue:  [205.8573944273258, 206.79534114230603]
# Arrivals Queue:  [205.8573944273258, 206.79534114230603, 208.79870139450688]
# Arrivals Queue:  [206.79534114230603, 208.79870139450688]
# Arrivals Queue:  [208.79870139450688]
# Arrivals Queue:  [208.79870139450688, 209.21454292345328]
# Arrivals Queue:  [208.79870139450688, 209.21454292345328, 209.47603302785276]
# Arrivals Queue:  [209.21454292345328, 209.47603302785276]
# Arrivals Queue:  [209.47603302785276]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [216.63757014712732]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [217.47678094924728]
# Arrivals Queue:  [217.47678094924728, 217.57399343862912]
# Arrivals Queue:  [217.57399343862912]
# Arrivals Queue:  [217.57399343862912, 217.84170060812195]
# Arrivals Queue:  [217.84170060812195]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [220.4319450883015]
# Arrivals Queue:  [220.4319450883015, 220.48739501052455]
# Arrivals Queue:  [220.48739501052455]
# Arrivals Queue:  [220.48739501052455, 221.69783918440888]
# Arrivals Queue:  [221.69783918440888]
# Arrivals Queue:  [221.69783918440888, 222.3299314445394]
# Arrivals Queue:  [222.3299314445394]
# Arrivals Queue:  [222.3299314445394, 223.8168629170789]
# Arrivals Queue:  [223.8168629170789]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [225.89405551778847]
# Arrivals Queue:  [225.89405551778847, 226.17635875205698]
# Arrivals Queue:  [225.89405551778847, 226.17635875205698, 226.21820725602782]
# Arrivals Queue:  [226.17635875205698, 226.21820725602782]
# Arrivals Queue:  [226.17635875205698, 226.21820725602782, 226.86332268661815]
# Arrivals Queue:  [226.21820725602782, 226.86332268661815]
# Arrivals Queue:  [226.86332268661815]
# Arrivals Queue:  []
# Arrivals Queue:  [228.085590699998]
# Arrivals Queue:  [228.085590699998, 229.56510613431294]
# Arrivals Queue:  [229.56510613431294]
# Arrivals Queue:  []
# Arrivals Queue:  [230.42986448534816]
# Arrivals Queue:  [230.42986448534816, 230.74295121792179]
# Arrivals Queue:  [230.74295121792179]
# Arrivals Queue:  [230.74295121792179, 231.40596500958748]
# Arrivals Queue:  [231.40596500958748]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [233.82376509375672]
# Arrivals Queue:  []
# Arrivals Queue:  [233.9223208622272]
# Arrivals Queue:  []
# Arrivals Queue:  [234.12731335437886]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [236.23967072735337]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [238.3604010594573]
# Arrivals Queue:  []
# Arrivals Queue:  [239.0156819928714]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [244.01162211107746]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [248.39710615390425]
# Arrivals Queue:  [248.39710615390425, 248.50451848655334]
# Arrivals Queue:  [248.39710615390425, 248.50451848655334, 248.63939706101365]
# Arrivals Queue:  [248.50451848655334, 248.63939706101365]
# Arrivals Queue:  [248.63939706101365]
# Arrivals Queue:  [248.63939706101365, 249.62573207888175]
# Arrivals Queue:  [249.62573207888175]
# Arrivals Queue:  [249.62573207888175, 250.3351915853866]
# Arrivals Queue:  [250.3351915853866]
# Arrivals Queue:  [250.3351915853866, 250.71256944872889]
# Arrivals Queue:  [250.3351915853866, 250.71256944872889, 250.74597697969043]
# Arrivals Queue:  [250.71256944872889, 250.74597697969043]
# Arrivals Queue:  [250.74597697969043]
# Arrivals Queue:  []
# Arrivals Queue:  [252.85594526713615]
# Arrivals Queue:  []
# Arrivals Queue:  [253.92304296015377]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [257.6995516041632]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [264.7932420653766]
# Arrivals Queue:  [264.7932420653766, 265.412266746179]
# Arrivals Queue:  [265.412266746179]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [268.8900995114818]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [274.76167856343324]
# Arrivals Queue:  []
# Arrivals Queue:  [275.49761698095585]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [282.2465925441371]
# Arrivals Queue:  [282.2465925441371, 282.91744665355844]
# Arrivals Queue:  [282.2465925441371, 282.91744665355844, 282.918430642844]
# Arrivals Queue:  [282.91744665355844, 282.918430642844]
# Arrivals Queue:  [282.918430642844]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [292.5524528980538]
# Arrivals Queue:  [292.5524528980538, 292.5546429018328]
# Arrivals Queue:  [292.5546429018328]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [296.04213208241055]
# Arrivals Queue:  []
# Arrivals Queue:  [296.2556517566078]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [297.94287441818693]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [302.1882530367273]
# Arrivals Queue:  []
# Arrivals Queue:  [302.26372320272975]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [308.25897877158206]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [311.61914633131886]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [315.0099476645256]
# Arrivals Queue:  []
# Arrivals Queue:  [315.1777643623699]
# Arrivals Queue:  [315.1777643623699, 315.4532469406887]
# Arrivals Queue:  [315.1777643623699, 315.4532469406887, 315.53367556148277]
# Arrivals Queue:  [315.4532469406887, 315.53367556148277]
# Arrivals Queue:  [315.53367556148277]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [322.94548945257674]
# Arrivals Queue:  [322.94548945257674, 323.4115548636109]
# Arrivals Queue:  [323.4115548636109]
# Arrivals Queue:  []
# Arrivals Queue:  [323.81877004426815]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [326.47597908655933]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [331.19048302549606]
# Arrivals Queue:  [331.19048302549606, 331.5374767714627]
# Arrivals Queue:  [331.19048302549606, 331.5374767714627, 331.60920944700126]
# Arrivals Queue:  [331.19048302549606, 331.5374767714627, 331.60920944700126, 332.3619284592569]
# Arrivals Queue:  [331.19048302549606, 331.5374767714627, 331.60920944700126, 332.3619284592569, 332.4841643874162]
# Arrivals Queue:  [331.5374767714627, 331.60920944700126, 332.3619284592569, 332.4841643874162]
# Arrivals Queue:  [331.60920944700126, 332.3619284592569, 332.4841643874162]
# Arrivals Queue:  [332.3619284592569, 332.4841643874162]
# Arrivals Queue:  [332.3619284592569, 332.4841643874162, 333.3893311274016]
# Arrivals Queue:  [332.4841643874162, 333.3893311274016]
# Arrivals Queue:  [333.3893311274016]
# Arrivals Queue:  []
# Arrivals Queue:  [333.7111010566008]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [337.40708453106737]
# Arrivals Queue:  [337.40708453106737, 339.0787388861104]
# Arrivals Queue:  [339.0787388861104]
# Arrivals Queue:  []
# Arrivals Queue:  [340.4277973091353]
# Arrivals Queue:  [340.4277973091353, 341.8164095529905]
# Arrivals Queue:  [341.8164095529905]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [346.3997843761614]
# Arrivals Queue:  []
# Arrivals Queue:  [346.63394287096656]
# Arrivals Queue:  [346.63394287096656, 347.27889347810833]
# Arrivals Queue:  [346.63394287096656, 347.27889347810833, 347.3691780573846]
# Arrivals Queue:  [347.27889347810833, 347.3691780573846]
# Arrivals Queue:  [347.3691780573846]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [353.9617528448518]
# Arrivals Queue:  []
# Arrivals Queue:  [355.6242507315239]
# Arrivals Queue:  [355.6242507315239, 356.25416001330916]
# Arrivals Queue:  [356.25416001330916]
# Arrivals Queue:  [356.25416001330916, 356.35468395862426]
# Arrivals Queue:  [356.35468395862426]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [362.31734630611254]
# Arrivals Queue:  [362.31734630611254, 362.52066734003364]
# Arrivals Queue:  [362.52066734003364]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [364.04972102963285]
# Arrivals Queue:  [364.04972102963285, 364.5714642402322]
# Arrivals Queue:  [364.04972102963285, 364.5714642402322, 364.6531370196176]
# Arrivals Queue:  [364.04972102963285, 364.5714642402322, 364.6531370196176, 365.44835229097225]
# Arrivals Queue:  [364.04972102963285, 364.5714642402322, 364.6531370196176, 365.44835229097225, 365.6443966161983]
# Arrivals Queue:  [364.5714642402322, 364.6531370196176, 365.44835229097225, 365.6443966161983]
# Arrivals Queue:  [364.6531370196176, 365.44835229097225, 365.6443966161983]
# Arrivals Queue:  [365.44835229097225, 365.6443966161983]
# Arrivals Queue:  [365.6443966161983]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [372.57489823602316]
# Arrivals Queue:  [372.57489823602316, 372.70624610509367]
# Arrivals Queue:  [372.57489823602316, 372.70624610509367, 372.7630444708477]
# Arrivals Queue:  [372.57489823602316, 372.70624610509367, 372.7630444708477, 373.0870604781381]
# Arrivals Queue:  [372.57489823602316, 372.70624610509367, 372.7630444708477, 373.0870604781381, 373.11709377857636]
# Arrivals Queue:  [372.57489823602316, 372.70624610509367, 372.7630444708477, 373.0870604781381, 373.11709377857636, 373.55747627984175]
# Arrivals Queue:  [372.70624610509367, 372.7630444708477, 373.0870604781381, 373.11709377857636, 373.55747627984175]
# Arrivals Queue:  [372.7630444708477, 373.0870604781381, 373.11709377857636, 373.55747627984175]
# Arrivals Queue:  [373.0870604781381, 373.11709377857636, 373.55747627984175]
# Arrivals Queue:  [373.11709377857636, 373.55747627984175]
# Arrivals Queue:  [373.11709377857636, 373.55747627984175, 376.5518643623498]
# Arrivals Queue:  [373.11709377857636, 373.55747627984175, 376.5518643623498, 376.640154925539]
# Arrivals Queue:  [373.55747627984175, 376.5518643623498, 376.640154925539]
# Arrivals Queue:  [373.55747627984175, 376.5518643623498, 376.640154925539, 377.30666145932184]
# Arrivals Queue:  [376.5518643623498, 376.640154925539, 377.30666145932184]
# Arrivals Queue:  [376.5518643623498, 376.640154925539, 377.30666145932184, 378.76893557396374]
# Arrivals Queue:  [376.640154925539, 377.30666145932184, 378.76893557396374]
# Arrivals Queue:  [377.30666145932184, 378.76893557396374]
# Arrivals Queue:  [377.30666145932184, 378.76893557396374, 379.21727471748784]
# Arrivals Queue:  [378.76893557396374, 379.21727471748784]
# Arrivals Queue:  [379.21727471748784]
# Arrivals Queue:  [379.21727471748784, 380.3477384971976]
# Arrivals Queue:  [379.21727471748784, 380.3477384971976, 380.36636156613423]
# Arrivals Queue:  [380.3477384971976, 380.36636156613423]
# Arrivals Queue:  [380.3477384971976, 380.36636156613423, 380.86673006465827]
# Arrivals Queue:  [380.36636156613423, 380.86673006465827]
# Arrivals Queue:  [380.36636156613423, 380.86673006465827, 381.3527706981012]
# Arrivals Queue:  [380.86673006465827, 381.3527706981012]
# Arrivals Queue:  [381.3527706981012]
# Arrivals Queue:  [381.3527706981012, 382.5768122861193]
# Arrivals Queue:  [382.5768122861193]
# Arrivals Queue:  [382.5768122861193, 383.6861640328157]
# Arrivals Queue:  [382.5768122861193, 383.6861640328157, 383.9509491742019]
# Arrivals Queue:  [382.5768122861193, 383.6861640328157, 383.9509491742019, 383.96650729903894]
# Arrivals Queue:  [382.5768122861193, 383.6861640328157, 383.9509491742019, 383.96650729903894, 384.0786537941811]
# Arrivals Queue:  [382.5768122861193, 383.6861640328157, 383.9509491742019, 383.96650729903894, 384.0786537941811, 384.47200202096684]
# Arrivals Queue:  [383.6861640328157, 383.9509491742019, 383.96650729903894, 384.0786537941811, 384.47200202096684]
# Arrivals Queue:  [383.9509491742019, 383.96650729903894, 384.0786537941811, 384.47200202096684]
# Arrivals Queue:  [383.96650729903894, 384.0786537941811, 384.47200202096684]
# Arrivals Queue:  [383.96650729903894, 384.0786537941811, 384.47200202096684, 387.250148092116]
# Arrivals Queue:  [384.0786537941811, 384.47200202096684, 387.250148092116]
# Arrivals Queue:  [384.47200202096684, 387.250148092116]
# Arrivals Queue:  [387.250148092116]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [390.8448467170005]
# Arrivals Queue:  [390.8448467170005, 390.87666922670184]
# Arrivals Queue:  [390.87666922670184]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [400.83760488231826]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [401.5257334673918]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [405.59640780216955]
# Arrivals Queue:  [405.59640780216955, 405.6293436636707]
# Arrivals Queue:  [405.59640780216955, 405.6293436636707, 405.8290705574689]
# Arrivals Queue:  [405.6293436636707, 405.8290705574689]
# Arrivals Queue:  [405.8290705574689]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [408.1184215591656]
# Arrivals Queue:  []
# Arrivals Queue:  [408.88309077712023]
# Arrivals Queue:  [408.88309077712023, 409.3885843208066]
# Arrivals Queue:  [409.3885843208066]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [417.9969193910339]
# Arrivals Queue:  []
# Arrivals Queue:  [418.58697050573676]
# Arrivals Queue:  []
# Arrivals Queue:  [418.6469540891002]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [419.1497083316715]
# Arrivals Queue:  [419.1497083316715, 419.26031813472383]
# Arrivals Queue:  [419.1497083316715, 419.26031813472383, 419.875955280653]
# Arrivals Queue:  [419.26031813472383, 419.875955280653]
# Arrivals Queue:  [419.875955280653]
# Arrivals Queue:  []
# Arrivals Queue:  [421.2161456044194]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [425.00721337481014]
# Arrivals Queue:  []
# Arrivals Queue:  [426.7223112491657]
# Arrivals Queue:  [426.7223112491657, 427.1517421749973]
# Arrivals Queue:  [427.1517421749973]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [429.1540361243902]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [433.6656063499709]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [435.5320953981012]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [436.5206507739103]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [443.78697826297093]
# Arrivals Queue:  [443.78697826297093, 444.0867807175005]
# Arrivals Queue:  [443.78697826297093, 444.0867807175005, 444.26391885573224]
# Arrivals Queue:  [443.78697826297093, 444.0867807175005, 444.26391885573224, 444.3435381113817]
# Arrivals Queue:  [444.0867807175005, 444.26391885573224, 444.3435381113817]
# Arrivals Queue:  [444.26391885573224, 444.3435381113817]
# Arrivals Queue:  [444.3435381113817]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [446.83531982856033]
# Arrivals Queue:  [446.83531982856033, 447.06308353258197]
# Arrivals Queue:  [446.83531982856033, 447.06308353258197, 447.29960624897456]
# Arrivals Queue:  [447.06308353258197, 447.29960624897456]
# Arrivals Queue:  [447.29960624897456]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [463.4515361094881]
# Arrivals Queue:  [463.4515361094881, 464.05008092297265]
# Arrivals Queue:  [464.05008092297265]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [470.47104444703604]
# Arrivals Queue:  []
# Arrivals Queue:  [471.0520199183884]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [473.9744495403801]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [480.26927610692286]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [482.154863972166]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [486.7200603072932]
# Arrivals Queue:  []
# Arrivals Queue:  [486.97693002856414]
# Arrivals Queue:  [486.97693002856414, 487.2940763143747]
# Arrivals Queue:  [486.97693002856414, 487.2940763143747, 488.7152140798227]
# Arrivals Queue:  [487.2940763143747, 488.7152140798227]
# Arrivals Queue:  [488.7152140798227]
# Arrivals Queue:  []
# Arrivals Queue:  [489.25476499750147]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [502.67870362530175]
# Arrivals Queue:  []
# Arrivals Queue:  [503.70886653305155]
# Arrivals Queue:  [503.70886653305155, 503.7767249696085]
# Arrivals Queue:  [503.7767249696085]
# Arrivals Queue:  []
# Arrivals Queue:  [506.16180287165236]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [514.4289898700515]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [518.0716575371238]
# Arrivals Queue:  [518.0716575371238, 518.8376805787309]
# Arrivals Queue:  [518.8376805787309]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [522.7388930831607]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [524.7244232659821]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [530.4792628291028]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [531.6523672870378]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [544.6603370911427]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [547.2769257861604]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [556.1003938910483]
# Arrivals Queue:  [556.1003938910483, 556.1352681055971]
# Arrivals Queue:  [556.1352681055971]
# Arrivals Queue:  [556.1352681055971, 556.9972224165732]
# Arrivals Queue:  [556.9972224165732]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [558.7702769785902]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [567.0482614559315]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [570.2550248621908]
# Arrivals Queue:  []
# Arrivals Queue:  [570.3184921447244]
# Arrivals Queue:  []
# Arrivals Queue:  [571.9792478668115]
# Arrivals Queue:  []
# Arrivals Queue:  [572.3693485154546]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [577.6028762904995]
# Arrivals Queue:  []
# Arrivals Queue:  [577.8183334150808]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [582.8298706718482]
# Arrivals Queue:  [582.8298706718482, 582.9397146633797]
# Arrivals Queue:  [582.8298706718482, 582.9397146633797, 583.0859470267349]
# Arrivals Queue:  [582.9397146633797, 583.0859470267349]
# Arrivals Queue:  [583.0859470267349]
# Arrivals Queue:  [583.0859470267349, 584.5769758841556]
# Arrivals Queue:  [584.5769758841556]
# Arrivals Queue:  []
# Arrivals Queue:  [585.3674955901566]
# Arrivals Queue:  []
# Arrivals Queue:  [585.8145128443263]
# Arrivals Queue:  []
# Arrivals Queue:  [586.3204378259044]
# Arrivals Queue:  [586.3204378259044, 586.3587209019463]
# Arrivals Queue:  [586.3204378259044, 586.3587209019463, 587.1893094043317]
# Arrivals Queue:  [586.3204378259044, 586.3587209019463, 587.1893094043317, 587.3323513792499]
# Arrivals Queue:  [586.3587209019463, 587.1893094043317, 587.3323513792499]
# Arrivals Queue:  [587.1893094043317, 587.3323513792499]
# Arrivals Queue:  [587.1893094043317, 587.3323513792499, 587.8419148659558]
# Arrivals Queue:  [587.1893094043317, 587.3323513792499, 587.8419148659558, 588.123326777137]
# Arrivals Queue:  [587.3323513792499, 587.8419148659558, 588.123326777137]
# Arrivals Queue:  [587.8419148659558, 588.123326777137]
# Arrivals Queue:  [588.123326777137]
# Arrivals Queue:  [588.123326777137, 589.6507858112454]
# Arrivals Queue:  [589.6507858112454]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [595.4497493322863]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [596.7444278215255]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [602.1900560578518]
# Arrivals Queue:  []
# Arrivals Queue:  [603.1217249364212]
# Arrivals Queue:  []
# Arrivals Queue:  [603.7182395263661]
# Arrivals Queue:  []
# Arrivals Queue:  [604.88884718648]
# Arrivals Queue:  [604.88884718648, 604.9952976615468]
# Arrivals Queue:  [604.9952976615468]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [609.4638852778851]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [619.1161376847341]
# Arrivals Queue:  [619.1161376847341, 619.5032784274026]
# Arrivals Queue:  [619.5032784274026]
# Arrivals Queue:  [619.5032784274026, 620.2738478666296]
# Arrivals Queue:  [620.2738478666296]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [622.5857258925756]
# Arrivals Queue:  [622.5857258925756, 622.9606509219055]
# Arrivals Queue:  [622.9606509219055]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [630.4169308547635]
# Arrivals Queue:  [630.4169308547635, 630.4349761007513]
# Arrivals Queue:  [630.4349761007513]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [638.5696871800333]
# Arrivals Queue:  []
# Arrivals Queue:  [639.2837836080457]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [640.2750392769705]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [665.5595808477628]
# Arrivals Queue:  [665.5595808477628, 666.0979945942242]
# Arrivals Queue:  [666.0979945942242]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [668.4189587244284]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [670.3830894447347]
# Arrivals Queue:  []
# Arrivals Queue:  [671.1799611898228]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [677.4995409791145]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [678.7053037857684]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [681.0737158171416]
# Arrivals Queue:  [681.0737158171416, 681.8385922290112]
# Arrivals Queue:  [681.8385922290112]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [688.2696530250244]
# Arrivals Queue:  [688.2696530250244, 688.2978321125421]
# Arrivals Queue:  [688.2978321125421]
# Arrivals Queue:  []
# Arrivals Queue:  [688.5065998471779]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [690.1970664715762]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [694.2167905474574]
# Arrivals Queue:  []
# Arrivals Queue:  [695.048477729926]
# Arrivals Queue:  []
# Arrivals Queue:  [695.3920751604035]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [705.5672685085708]
# Arrivals Queue:  []
# Arrivals Queue:  [706.9343650304633]
# Arrivals Queue:  [706.9343650304633, 707.5888636550981]
# Arrivals Queue:  [707.5888636550981]
# Arrivals Queue:  [707.5888636550981, 710.6968514324861]
# Arrivals Queue:  [710.6968514324861]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [712.4647228150327]
# Arrivals Queue:  []
# Arrivals Queue:  [713.7033823062422]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [716.7257609731861]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [719.1475018250356]
# Arrivals Queue:  []
# Arrivals Queue:  [719.3204591805952]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [735.3173687269752]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [740.9007857869314]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [746.1986069957643]
# Arrivals Queue:  [746.1986069957643, 746.2368388461224]
# Arrivals Queue:  [746.2368388461224]
# Arrivals Queue:  [746.2368388461224, 747.0677730084135]
# Arrivals Queue:  [746.2368388461224, 747.0677730084135, 747.1557191214566]
# Arrivals Queue:  [747.0677730084135, 747.1557191214566]
# Arrivals Queue:  [747.1557191214566]
# Arrivals Queue:  [747.1557191214566, 748.801902438337]
# Arrivals Queue:  [747.1557191214566, 748.801902438337, 748.8193253341051]
# Arrivals Queue:  [748.801902438337, 748.8193253341051]
# Arrivals Queue:  [748.8193253341051]
# Arrivals Queue:  [748.8193253341051, 750.9169109502196]
# Arrivals Queue:  [748.8193253341051, 750.9169109502196, 751.0186445020166]
# Arrivals Queue:  [748.8193253341051, 750.9169109502196, 751.0186445020166, 751.0544915452042]
# Arrivals Queue:  [750.9169109502196, 751.0186445020166, 751.0544915452042]
# Arrivals Queue:  [750.9169109502196, 751.0186445020166, 751.0544915452042, 752.0517022884338]
# ...
# Arrivals Queue:  [9758.763720617982, 9758.799939220931]
# Arrivals Queue:  [9758.799939220931]
# Arrivals Queue:  [9758.799939220931, 9759.461741844021]
# Arrivals Queue:  [9759.461741844021]
# Arrivals Queue:  [9759.461741844021, 9760.19622688236]
# Arrivals Queue:  [9760.19622688236]
# Arrivals Queue:  [9760.19622688236, 9760.298370438424]
# Arrivals Queue:  [9760.19622688236, 9760.298370438424, 9760.331518926367]
# Arrivals Queue:  [9760.298370438424, 9760.331518926367]
# Arrivals Queue:  [9760.331518926367]
# Arrivals Queue:  [9760.331518926367, 9761.23055191088]
# Arrivals Queue:  [9761.23055191088]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [9763.702807951942]
# Arrivals Queue:  [9763.702807951942, 9763.838869650808]
# Arrivals Queue:  [9763.838869650808]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [9769.30940596746]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [9773.22754903217]
# Arrivals Queue:  [9773.22754903217, 9773.632931654522]
# Arrivals Queue:  [9773.22754903217, 9773.632931654522, 9773.70780780676]
# Arrivals Queue:  [9773.632931654522, 9773.70780780676]
# Arrivals Queue:  [9773.70780780676]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [9776.36366164339]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [9778.512937433963]
# Arrivals Queue:  [9778.512937433963, 9778.534358129855]
# Arrivals Queue:  [9778.534358129855]
# Arrivals Queue:  [9778.534358129855, 9779.05424645195]
# Arrivals Queue:  [9778.534358129855, 9779.05424645195, 9779.15247760105]
# Arrivals Queue:  [9779.05424645195, 9779.15247760105]
# Arrivals Queue:  [9779.05424645195, 9779.15247760105, 9779.481980194878]
# Arrivals Queue:  [9779.15247760105, 9779.481980194878]
# Arrivals Queue:  [9779.481980194878]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [9786.36670618418]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [9789.63440266768]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [9791.003030483209]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [9792.566431375011]
# Arrivals Queue:  []
# Arrivals Queue:  [9793.985268128008]
# Arrivals Queue:  [9793.985268128008, 9794.321249956196]
# Arrivals Queue:  [9794.321249956196]
# Arrivals Queue:  []
# Arrivals Queue:  [9795.793805161467]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [9798.77683643192]
# Arrivals Queue:  []
# Arrivals Queue:  [9799.910521338257]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [9805.586332223913]
# Arrivals Queue:  [9805.586332223913, 9805.614259272943]
# Arrivals Queue:  [9805.614259272943]
# Arrivals Queue:  []
# Arrivals Queue:  [9805.790270667023]
# Arrivals Queue:  [9805.790270667023, 9805.817994346222]
# Arrivals Queue:  [9805.790270667023, 9805.817994346222, 9806.16396421002]
# Arrivals Queue:  [9805.790270667023, 9805.817994346222, 9806.16396421002, 9806.692227052657]
# Arrivals Queue:  [9805.790270667023, 9805.817994346222, 9806.16396421002, 9806.692227052657, 9807.183475406926]
# Arrivals Queue:  [9805.817994346222, 9806.16396421002, 9806.692227052657, 9807.183475406926]
# Arrivals Queue:  [9806.16396421002, 9806.692227052657, 9807.183475406926]
# Arrivals Queue:  [9806.692227052657, 9807.183475406926]
# Arrivals Queue:  [9807.183475406926]
# Arrivals Queue:  []
# Arrivals Queue:  [9808.92806601042]
# Arrivals Queue:  []
# Arrivals Queue:  [9809.214754565037]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [9811.739555355785]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [9812.78191261826]
# Arrivals Queue:  [9812.78191261826, 9812.96903801803]
# Arrivals Queue:  [9812.78191261826, 9812.96903801803, 9813.014689617265]
# Arrivals Queue:  [9812.78191261826, 9812.96903801803, 9813.014689617265, 9813.129414149165]
# Arrivals Queue:  [9812.96903801803, 9813.014689617265, 9813.129414149165]
# Arrivals Queue:  [9813.014689617265, 9813.129414149165]
# Arrivals Queue:  [9813.129414149165]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [9819.898215468133]
# Arrivals Queue:  [9819.898215468133, 9820.659064216867]
# Arrivals Queue:  [9820.659064216867]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [9829.030836092537]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [9834.515140259073]
# Arrivals Queue:  [9834.515140259073, 9835.326528668002]
# Arrivals Queue:  [9834.515140259073, 9835.326528668002, 9835.345210711444]
# Arrivals Queue:  [9835.326528668002, 9835.345210711444]
# Arrivals Queue:  [9835.345210711444]
# Arrivals Queue:  []
# Arrivals Queue:  [9836.845429373876]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [9840.394135211422]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [9841.911355556625]
# Arrivals Queue:  [9841.911355556625, 9841.960562077238]
# Arrivals Queue:  [9841.911355556625, 9841.960562077238, 9842.179213945554]
# Arrivals Queue:  [9841.911355556625, 9841.960562077238, 9842.179213945554, 9842.569201981116]
# Arrivals Queue:  [9841.911355556625, 9841.960562077238, 9842.179213945554, 9842.569201981116, 9842.872169393777]
# Arrivals Queue:  [9841.911355556625, 9841.960562077238, 9842.179213945554, 9842.569201981116, 9842.872169393777, 9843.410566011282]
# Arrivals Queue:  [9841.960562077238, 9842.179213945554, 9842.569201981116, 9842.872169393777, 9843.410566011282]
# Arrivals Queue:  [9842.179213945554, 9842.569201981116, 9842.872169393777, 9843.410566011282]
# Arrivals Queue:  [9842.179213945554, 9842.569201981116, 9842.872169393777, 9843.410566011282, 9844.2371508869]
# Arrivals Queue:  [9842.179213945554, 9842.569201981116, 9842.872169393777, 9843.410566011282, 9844.2371508869, 9844.329640818129]
# Arrivals Queue:  [9842.569201981116, 9842.872169393777, 9843.410566011282, 9844.2371508869, 9844.329640818129]
# Arrivals Queue:  [9842.569201981116, 9842.872169393777, 9843.410566011282, 9844.2371508869, 9844.329640818129, 9845.841619124756]
# Arrivals Queue:  [9842.872169393777, 9843.410566011282, 9844.2371508869, 9844.329640818129, 9845.841619124756]
# Arrivals Queue:  [9843.410566011282, 9844.2371508869, 9844.329640818129, 9845.841619124756]
# Arrivals Queue:  [9844.2371508869, 9844.329640818129, 9845.841619124756]
# Arrivals Queue:  [9844.2371508869, 9844.329640818129, 9845.841619124756, 9847.139597509684]
# Arrivals Queue:  [9844.329640818129, 9845.841619124756, 9847.139597509684]
# Arrivals Queue:  [9845.841619124756, 9847.139597509684]
# Arrivals Queue:  [9847.139597509684]
# Arrivals Queue:  [9847.139597509684, 9849.305405102932]
# Arrivals Queue:  [9849.305405102932]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [9853.519778597773]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [9855.523583007112]
# Arrivals Queue:  [9855.523583007112, 9855.956731419476]
# Arrivals Queue:  [9855.956731419476]
# Arrivals Queue:  [9855.956731419476, 9856.846693986912]
# Arrivals Queue:  [9855.956731419476, 9856.846693986912, 9857.358703810747]
# Arrivals Queue:  [9856.846693986912, 9857.358703810747]
# Arrivals Queue:  [9857.358703810747]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [9865.266903007643]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [9867.163239543721]
# Arrivals Queue:  []
# Arrivals Queue:  [9867.492213223173]
# Arrivals Queue:  [9867.492213223173, 9868.380354017341]
# Arrivals Queue:  [9867.492213223173, 9868.380354017341, 9868.786481188257]
# Arrivals Queue:  [9868.380354017341, 9868.786481188257]
# Arrivals Queue:  [9868.786481188257]
# Arrivals Queue:  [9868.786481188257, 9869.19221734896]
# Arrivals Queue:  [9869.19221734896]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [9874.91703385828]
# Arrivals Queue:  [9874.91703385828, 9875.456036385542]
# Arrivals Queue:  [9875.456036385542]
# Arrivals Queue:  [9875.456036385542, 9877.102710014255]
# Arrivals Queue:  [9877.102710014255]
# Arrivals Queue:  [9877.102710014255, 9877.128528565023]
# Arrivals Queue:  [9877.128528565023]
# Arrivals Queue:  [9877.128528565023, 9878.00489321449]
# Arrivals Queue:  [9878.00489321449]
# Arrivals Queue:  [9878.00489321449, 9878.58337292635]
# Arrivals Queue:  [9878.58337292635]
# Arrivals Queue:  []
# Arrivals Queue:  [9879.068802094263]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [9884.855455028242]
# Arrivals Queue:  [9884.855455028242, 9885.017723425684]
# Arrivals Queue:  [9885.017723425684]
# Arrivals Queue:  [9885.017723425684, 9885.747726728418]
# Arrivals Queue:  [9885.747726728418]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [9891.045072556815]
# Arrivals Queue:  []
# Arrivals Queue:  [9891.800969001026]
# Arrivals Queue:  []
# Arrivals Queue:  [9892.264033965492]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [9898.938063552607]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [9902.422621255831]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [9903.752453596124]
# Arrivals Queue:  []
# Arrivals Queue:  [9903.87782382602]
# Arrivals Queue:  [9903.87782382602, 9904.130025745835]
# Arrivals Queue:  [9903.87782382602, 9904.130025745835, 9904.255437875703]
# Arrivals Queue:  [9903.87782382602, 9904.130025745835, 9904.255437875703, 9904.591446962373]
# Arrivals Queue:  [9903.87782382602, 9904.130025745835, 9904.255437875703, 9904.591446962373, 9904.745034807165]
# Arrivals Queue:  [9903.87782382602, 9904.130025745835, 9904.255437875703, 9904.591446962373, 9904.745034807165, 9904.823431309895]
# Arrivals Queue:  [9904.130025745835, 9904.255437875703, 9904.591446962373, 9904.745034807165, 9904.823431309895]
# Arrivals Queue:  [9904.255437875703, 9904.591446962373, 9904.745034807165, 9904.823431309895]
# Arrivals Queue:  [9904.591446962373, 9904.745034807165, 9904.823431309895]
# Arrivals Queue:  [9904.591446962373, 9904.745034807165, 9904.823431309895, 9906.095153321587]
# Arrivals Queue:  [9904.745034807165, 9904.823431309895, 9906.095153321587]
# Arrivals Queue:  [9904.823431309895, 9906.095153321587]
# Arrivals Queue:  [9906.095153321587]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [9909.478796369687]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [9910.42160139125]
# Arrivals Queue:  [9910.42160139125, 9910.70705262378]
# Arrivals Queue:  [9910.70705262378]
# Arrivals Queue:  [9910.70705262378, 9911.0250233805]
# Arrivals Queue:  [9910.70705262378, 9911.0250233805, 9911.781284391187]
# Arrivals Queue:  [9911.0250233805, 9911.781284391187]
# Arrivals Queue:  [9911.0250233805, 9911.781284391187, 9912.132962023838]
# Arrivals Queue:  [9911.781284391187, 9912.132962023838]
# Arrivals Queue:  [9912.132962023838]
# Arrivals Queue:  []
# Arrivals Queue:  [9913.352599409338]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [9917.079837235558]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [9918.617122925634]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [9925.28292284476]
# Arrivals Queue:  []
# Arrivals Queue:  [9926.011646260484]
# Arrivals Queue:  [9926.011646260484, 9926.07930044016]
# Arrivals Queue:  [9926.07930044016]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [9928.584026422637]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [9941.441036024104]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [9944.14330173544]
# Arrivals Queue:  [9944.14330173544, 9944.361297889123]
# Arrivals Queue:  [9944.14330173544, 9944.361297889123, 9944.650813922453]
# Arrivals Queue:  [9944.361297889123, 9944.650813922453]
# Arrivals Queue:  [9944.361297889123, 9944.650813922453, 9945.15899998745]
# Arrivals Queue:  [9944.361297889123, 9944.650813922453, 9945.15899998745, 9945.309664361186]
# Arrivals Queue:  [9944.650813922453, 9945.15899998745, 9945.309664361186]
# Arrivals Queue:  [9945.15899998745, 9945.309664361186]
# Arrivals Queue:  [9945.309664361186]
# Arrivals Queue:  []
# Arrivals Queue:  [9947.189476808948]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [9947.538192331638]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [9970.368812620542]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [9971.498457484407]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  [9986.537367962987]
# Arrivals Queue:  [9986.537367962987, 9987.062767142726]
# Arrivals Queue:  [9987.062767142726]
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# Arrivals Queue:  []
# {'average_waiting_time': 0.5001206975369009, 'average_clients_in_system': 1.0096922027306001}
